# %%
from pylab import *

# %%
x = linspace (-pi,pi,2000) # 400 reichen aus

# %%
print(x)
# Out:
# [-3.14159265 -3.13844949 -3.13530633 ...,  3.13530633  3.13844949
#   3.14159265]

# %%
a = sin(x)*sin(5*x)

# %%
b = cos(x)*sin(5*x)

# %%
# %matplotlib inline

# %%
#plot(a,b) # andersherum !
plt.ylim([-1., 1.1]) # damit ist die ganze Kurve sichtbar
plot(b,a)
show() # durch diese Zeile entfaellt [<matplotlib.lines.Line2D at 0x10cedc588>] ueber dem plot

# 10 Punkte
